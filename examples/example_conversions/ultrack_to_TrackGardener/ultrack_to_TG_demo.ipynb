# %% [markdown]
# ## Example: Converting an Ultrack Tracking Results for Use with TrackGardener

# %%
from sqlalchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 from sqlalchemy import create_engine
#       2 from sqlalchemy.orm import Session
# ----> 4 from ultrack.core.export.utils import solution_dataframe_from_sql
#
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\gardener-env3\Lib\site-packages\ultrack\__init__.py:16
#      13 __version__ = "0.6.3"
#      15 from ultrack.config.config import MainConfig, load_config
# ---> 16 from ultrack.core.export.ctc import to_ctc
#      17 from ultrack.core.export.exporter import export_tracks_by_extension
#      18 from ultrack.core.export.trackmate import to_trackmate
#
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\gardener-env3\Lib\site-packages\ultrack\core\export\__init__.py:1
# ----> 1 from ultrack.core.export.ctc import to_ctc
# ...

# %%
ultrack_db_path = 'data.db'
engine_ultrack = create_engine(f'sqlite:///{ultrack_db_path}')
